# %%
import pandas as pd
import regex as re
import time
import datetime
import os
import shutil
import tkinter as tk
from tkinter import *
from tkinter import filedialog
from tkinter import messagebox as msg
from tkinter.filedialog import askdirectory


def filterNumber(num):
    if(len(num) >= 5):
        return True
    else:
        return False

def lst_to_str(str):
    x = re.findall('[0-9]+', str)
    finalx = list(filter(filterNumber, x))
    if len(finalx) == 0:
        return ""
    elif len(finalx) > 1:
        return finalx[-1].lstrip("0")
    else:
        return finalx[0].lstrip("0")
        

class extract_vpn:
   
    def __init__(self,init_window_name):
        self.init_window_name = init_window_name
        self.path = StringVar()

    def selectFile(self):
        self.file_name = filedialog.askopenfilename(initialdir='./',
                                                    title = 'Select an Excel file',
                                                    filetypes = [("xlsx", "*.xlsx"), ('CSV', '*.csv'), 
                                                                 ('PDF', '*.pdf'), ('TEXT', '*.txt')])

    def error(self):    # pop up window
        tk.messagebox.showinfo(title="Warning", message="No File Selected")
        
    def uptime(self):   # update time
        TimeLabel["text"] = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S:') + "%d" % (datetime.datetime.now().microsecond // 100000)
        self.init_window_name.after(100, self.uptime)        
    
    def set_init_window(self):
        # set Window
        self.init_window_name.title("VPN Extraction")               # Window Title Bar
        self.init_window_name.geometry('300x300+600+300')           # Window size: 300x300，left margin: +600，top margin: +300
        self.init_window_name.resizable(width=FALSE,height=FALSE)   # fixed window size
        Label(self.init_window_name,text="Extracting VPN from Free Text",bg="SkyBlue",fg="Gray").place(x=70,y=10)  # label component
        Button(self.init_window_name,text="Select File",command=self.selectFile,bg="SkyBlue").place(width=200,height=50,x=50,y=45)   # button component to trigger functions
        Button(self.init_window_name,text="Process",bg="SkyBlue",command=self.processFile).place(width=200,height=50,x=50,y=115)
        Button(self.init_window_name,text="Exit",bg="SkyBlue",command=self.init_window_name.destroy).place(width=200,height=50, x=50, y=185)
        self.init_window_name["bg"] = "SkyBlue"     # window background colour
        self.init_window_name.attributes("-alpha")  #  opacity/transparency
        global TimeLabel
        TimeLabel = Label(text="%s%d" % (datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S:'),datetime.datetime.now().microsecond // 100000),bg="SkyBlue")
        TimeLabel.place(x=80, y=260)
        self.init_window_name.after(100, self.uptime)
        
    def processFile(self):
        df_sheet_map = pd.read_excel(self.file_name, header=1, sheet_name=None)
        
        # Create a Pandas Excel writer using XlsxWriter as the engine
        writer = pd.ExcelWriter('extraction.xlsx', engine='xlsxwriter')

        for key in df_sheet_map.keys():
            data = df_sheet_map[key]
            if (len(data) == 0):      
                    msg.showinfo('No Rows Selected', 'Excel has no rows')
            else:
                data['SHORT TEXT'] = data['SHORT TEXT'].str.replace(" ","")
                data['SHORT TEXT'] = data['SHORT TEXT'].fillna("Missing")
                data['extrVPN'] = data['SHORT TEXT'].apply(lst_to_str)
                data.to_excel(writer, sheet_name=key, index = False)

        # Close the Pandas Excel writer and output the Excel file
        writer.save()
        
        msg.showinfo(title="Well", message="Done")
            
    def get_current_time(self):
        # Get current time
        current_time = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time()))
        return current_time 
    
                
if __name__ == '__main__':
    init_window = Tk()    # instantiate a parent window
    VPN_PORTAL = extract_vpn(init_window)
    VPN_PORTAL.set_init_window()
    init_window.mainloop()

# %% [markdown]
# - Generate .py file
# - Go to cmd to install: python -m pip install --upgrade 'packages' (e.g., regex, openpyxl, xlsxwriter, pyinstaller)
# - In cmd to run: pyinstaller -F -i label.ico extrVPNproj.py -n VPNextraction --noconsole

# %%
import pyforest

# %%
def filterNumber(num):
    if(len(num) >= 5):
        return True
    else:
        return False

def lst_to_str(str):
    x = re.findall('[0-9]+', str)
    finalx = list(filter(filterNumber, x))
    if len(finalx) == 0:
        return ""
    elif len(finalx) > 1:
        return finalx[-1].lstrip("0")
    else:
        return finalx[0].lstrip("0")

# %%
str = 'QA#200920 - 0917760 NUT'

# %%
lst_to_str(str)
# Out:
# '917760'

# %%
df_sheet_map = pd.read_excel("Wurth & Galvins Plumbing.xlsx", header=1, sheet_name=None)

# %%
type(df_sheet_map)
# Out:
# dict

# %%
df_sheet_map.keys()
# Out:
# dict_keys(['Galvins', 'Wurth'])

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine
writer = pd.ExcelWriter('extraction.xlsx', engine='xlsxwriter')

for key in df_sheet_map.keys():
    data = df_sheet_map[key]
    if (len(data) == 0):      
            msg.showinfo('No Rows Selected', 'Excel has no rows')
    else:
        data['SHORT TEXT'] = data['SHORT TEXT'].str.replace(" ","")
        data['SHORT TEXT'] = data['SHORT TEXT'].fillna("Missing")
        data['extrVPN'] = data['SHORT TEXT'].apply(lst_to_str)
        data.to_excel(writer, sheet_name=key, index = False)

# Close the Pandas Excel writer and output the Excel file
writer.save()

# %%
df_sheet_map['Galvins']
# Out:
#      Order Source CONCAT [Company].[Material] , [Company].[Short Text]  \
# 0        Material                                       300020046144
# 1        Material                                       300020046150
# 2        Material                                       300020046184
# 3        Material                                       300020046197
# 4        Material                                       300020046227
# ...           ...                                                ...
# 1690    Free-Text       5000SS REPAIR CLAMP 80AC/BB 95-104X200 CR103
# 1691    Free-Text       5000TUBE LOXEAL GAS THREAD SEALANT 100ML (18
# 1692    Free-Text       5000TUBE LOXEAL GAS THREAD SEALANT 100ML (58
# 1693    Free-Text       5000UNIVERSAL BOTTOM INLET CISTERN VALVE #PR
# 1694    Free-Text       5000ZIP NEW STYLE FLOAT VALVE KIT (>1994) #9
#
#        MATERIAL  COMPANY CODE              COMPANY NAME  \
# 0      20046144          3000  Pilbara Iron Co Serv P/L
# 1      20046150          3000  Pilbara Iron Co Serv P/L
# 2      20046184          3000  Pilbara Iron Co Serv P/L
# 3      20046197          3000  Pilbara Iron Co Serv P/L
# 4      20046227          3000  Pilbara Iron Co Serv P/L
# ...         ...           ...                       ...
# 1690  Free-Text          5000   Argyle Diamonds Limited
# 1691  Free-Text          5000   Argyle Diamonds Limited
# 1692  Free-Text          5000   Argyle Diamonds Limited
# 1693  Free-Text          5000   Argyle Diamonds Limited
# 1694  Free-Text          5000   Argyle Diamonds Limited
#
#                                     SHORT TEXT  \
# 0     TAP,MIXER LEVER;CHROME;BASIN;ENHNCE SINK
# 1      HOSE ASSY;FLEX;10HOSE 15BSPX600 F/F F/S
# 2          PIPE;32MM;GALV-STL MED SCREWED 6.5M
# 3       TRAP;S&P COMB;POLY;CAROMA HITEMAKER 40
# 4                 SOCKET;BSP;POLY;SCREWED;32MM
# ...                                        ...
# 1690  SS REPAIR CLAMP 80AC/BB 95-104X200 CR103
# 1691  TUBE LOXEAL GAS THREAD SEALANT 100ML (18
# 1692  TUBE LOXEAL GAS THREAD SEALANT 100ML (58
# 1693  UNIVERSAL BOTTOM INLET CISTERN VALVE #PR
# 1694  ZIP NEW STYLE FLOAT VALVE KIT (>1994) #9
#
#                                      LONG TEXT CLEAN VPN CLEAN MPN  \
# 0     TAP,MIXER LEVER;CHROME;BASIN;ENHNCE SINK    424230    424230
# 1      HOSE ASSY;FLEX;10HOSE 15BSPX600 F/F F/S     34750     34750
# 2          PIPE;32MM;GALV-STL MED SCREWED 6.5M    150045    150045
# 3       TRAP;S&P COMB;POLY;CAROMA HITEMAKER 40    111328    111385
# 4                 SOCKET;BSP;POLY;SCREWED;32MM     98285     98285
# ...                                        ...       ...       ...
# 1690                                       NaN       NaN       NaN
# 1691                                       NaN       NaN       NaN
# 1692                                       NaN       NaN       NaN
# 1693                                       NaN        PR       NaN
# 1694                                       NaN         9       NaN
#
#             SUBCATEGORY  ... PURCHASING UOM STD PACK SIZE Bin Hits  \
# 0     Materials - other  ...             EA            EA        4
# 1                Valves  ...             AY            AY        4
# 2                Valves  ...             LN            LN        2
# 3                Valves  ...             EA            EA        1
# 4                Valves  ...             EA            EA        1
# ...                 ...  ...            ...           ...      ...
# 1690                  #  ...              #             #        1
# 1691                  #  ...              #             #        1
# 1692                  #  ...              #             #        1
# 1693                  #  ...              #             #        3
# 1694                  #  ...              #             #        1
#
#       Total Spend   Common D   BHP 3.4  Common D M  BHP 3.4 M  Coding Team  \
# 0      421.000000   360149.0  360149.0    360149.0   360149.0          NaN
# 1       75.390000  3056200.0       NaN   3056200.0        NaN          NaN
# 2      424.920000        NaN       NaN         NaN        NaN          NaN
# 3       10.100000        NaN       NaN         NaN        NaN          NaN
# 4        4.600000        NaN       NaN         NaN        NaN          NaN
# ...           ...        ...       ...         ...        ...          ...
# 1690   747.308571        NaN       NaN         NaN        NaN          NaN
# 1691   180.068571        NaN       NaN         NaN        NaN          NaN
# 1692    82.080000        NaN       NaN         NaN        NaN          NaN
# 1693  2433.685714        NaN       NaN         NaN        NaN          NaN
# 1694  3009.600000        NaN       NaN         NaN        NaN          NaN
#
#       Right Product
# 0          360149.0
# 1         3056200.0
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 1690            0.0
# 1691            0.0
# 1692            0.0
# 1693            0.0
# 1694            0.0
#
# [1695 rows x 22 columns]

# %%
# Read the excel file and get a list of sheets
xls = pd.ExcelFile('Wurth & Galvins Plumbing.xlsx')

# %%
xls.sheet_names
# Out:
# ['Galvins', 'Wurth']

# %%
# Read all sheets to a map
sheet_to_df_map = {}
for sheet_name in xls.sheet_names:
    sheet_to_df_map[sheet_name] = xls.parse(sheet_name)
    # can also use sheet_index[0,1,2..] instead of sheet name

# %%
sheet_to_df_map
# Out:
# {'Galvins':         Unnamed: 0                                         Unnamed: 1  \
#  0     Order Source  CONCAT [Company].[Material] , [Company].[Short...
#  1         Material                                       300020046144
#  2         Material                                       300020046150
#  3         Material                                       300020046184
#  4         Material                                       300020046197
#  ...            ...                                                ...
#  1691     Free-Text       5000SS REPAIR CLAMP 80AC/BB 95-104X200 CR103
#  1692     Free-Text       5000TUBE LOXEAL GAS THREAD SEALANT 100ML (18
#  1693     Free-Text       5000TUBE LOXEAL GAS THREAD SEALANT 100ML (58
#  1694     Free-Text       5000UNIVERSAL BOTTOM INLET CISTERN VALVE #PR
#  1695     Free-Text       5000ZIP NEW STYLE FLOAT VALVE KIT (>1994) #9
#
#       Unnamed: 2    Unnamed: 3                Unnamed: 4  \
#  0      MATERIAL  COMPANY CODE              COMPANY NAME
#  1      20046144          3000  Pilbara Iron Co Serv P/L
#  2      20046150          3000  Pilbara Iron Co Serv P/L
#  3      20046184          3000  Pilbara Iron Co Serv P/L
#  4      20046197          3000  Pilbara Iron Co Serv P/L
#  ...         ...           ...                       ...
#  1691  Free-Text          5000   Argyle Diamonds Limited
#  1692  Free-Text          5000   Argyle Diamonds Limited
#  1693  Free-Text          5000   Argyle Diamonds Limited
#  1694  Free-Text          5000   Argyle Diamonds Limited
#  1695  Free-Text          5000   Argyle Diamonds Limited
#
#                                      Unnamed: 5  \
#  0                                   SHORT TEXT
#  1     TAP,MIXER LEVER;CHROME;BASIN;ENHNCE SINK
#  2      HOSE ASSY;FLEX;10HOSE 15BSPX600 F/F F/S
#  3          PIPE;32MM;GALV-STL MED SCREWED 6.5M
#  4       TRAP;S&P COMB;POLY;CAROMA HITEMAKER 40
#  ...                                        ...
#  1691  SS REPAIR CLAMP 80AC/BB 95-104X200 CR103
#  1692  TUBE LOXEAL GAS THREAD SEALANT 100ML (18
#  1693  TUBE LOXEAL GAS THREAD SEALANT 100ML (58
#  1694  UNIVERSAL BOTTOM INLET CISTERN VALVE #PR
#  1695  ZIP NEW STYLE FLOAT VALVE KIT (>1994) #9
#
#                                      Unnamed: 6 Unnamed: 7 Unnamed: 8  \
#  0                                    LONG TEXT  CLEAN VPN  CLEAN MPN
#  1     TAP,MIXER LEVER;CHROME;BASIN;ENHNCE SINK     424230     424230
#  2      HOSE ASSY;FLEX;10HOSE 15BSPX600 F/F F/S      34750      34750
#  3          PIPE;32MM;GALV-STL MED SCREWED 6.5M     150045     150045
#  4       TRAP;S&P COMB;POLY;CAROMA HITEMAKER 40     111328     111385
#  ...                                        ...        ...        ...
#  1691                                       NaN        NaN        NaN
#  1692                                       NaN        NaN        NaN
#  1693                                       NaN        NaN        NaN
#  1694                                       NaN         PR        NaN
#  1695                                       NaN          9        NaN
#
#               Unnamed: 9  ...     Unnamed: 12    Unnamed: 13 Unnamed: 14  \
#  0           SUBCATEGORY  ...  PURCHASING UOM  STD PACK SIZE    Bin Hits
#  1     Materials - other  ...              EA             EA           4
#  2                Valves  ...              AY             AY           4
#  3                Valves  ...              LN             LN           2
#  4                Valves  ...              EA             EA           1
#  ...                 ...  ...             ...            ...         ...
#  1691                  #  ...               #              #           1
#  1692                  #  ...               #              #           1
#  1693                  #  ...               #              #           1
#  1694                  #  ...               #              #           3
#  1695                  #  ...               #              #           1
#
#        Unnamed: 15       VPN Unnamed: 17         MPN Unnamed: 19  Unnamed: 20  \
#  0     Total Spend  Common D     BHP 3.4  Common D M   BHP 3.4 M  Coding Team
#  1             421  00360149    00360149    00360149    00360149          NaN
#  2           75.39  03056200         NaN    03056200         NaN          NaN
#  3          424.92       NaN         NaN         NaN         NaN          NaN
#  4            10.1       NaN         NaN         NaN         NaN          NaN
#  ...           ...       ...         ...         ...         ...          ...
#  1691   747.308571       NaN         NaN         NaN         NaN          NaN
#  1692   180.068571       NaN         NaN         NaN         NaN          NaN
#  1693        82.08       NaN         NaN         NaN         NaN          NaN
#  1694  2433.685714       NaN         NaN         NaN         NaN          NaN
#  1695       3009.6       NaN         NaN         NaN         NaN          NaN
#
#          Unnamed: 21
#  0     Right Product
#  1          00360149
#  2          03056200
#  3               NaN
#  4               NaN
#  ...             ...
#  1691              0
#  1692              0
#  1693              0
#  1694              0
#  1695              0
#
#  [1696 rows x 22 columns],
#  'Wurth':         Unnamed: 0                                         Unnamed: 1  \
#  0     Order Source  CONCAT [Company].[Material] , [Company].[Short...
#  1         Material                                       300020086567
#  2         Material                                       300020105242
#  3         Material                                       300020105243
#  4         Material                                       300020114303
#  ...            ...                                                ...
#  1750     Free-Text       21905964056100 Cable sleeve 200 pieces Sysko
#  1751     Free-Text                        30005964073105 - Blade fuse
#  1752     Free-Text          30005964076402 - Air-conditioning, ORings
#  1753     Free-Text                         30005964511701 - Split Pin
#  1754     Free-Text                                 36005964558000 Kit
#
#       Unnamed: 2    Unnamed: 3                Unnamed: 4  \
#  0      MATERIAL  COMPANY CODE              COMPANY NAME
#  1      20086567          3000  Pilbara Iron Co Serv P/L
#  2      20105242          3000  Pilbara Iron Co Serv P/L
#  3      20105243          3000  Pilbara Iron Co Serv P/L
#  4      20114303          3000  Pilbara Iron Co Serv P/L
#  ...         ...           ...                       ...
#  1750  Free-Text          2190         RTA Weipa Pty Ltd
#  1751  Free-Text          3000  Pilbara Iron Co Serv P/L
#  1752  Free-Text          3000  Pilbara Iron Co Serv P/L
#  1753  Free-Text          3000  Pilbara Iron Co Serv P/L
#  1754  Free-Text          3600      Dampier Salt Limited
#
#                                      Unnamed: 5  \
#  0                                   SHORT TEXT
#  1                    PIN,CONNECTOR;CAT;1809339
#  2       BURR;TUNG-CARB;CYLINDRICAL;6.3X21.64MM
#  3             BURR;TUNG-CARB,ARCHED,13X25X76MM
#  4              SPRAY;300ML;COPPER GREASE;CU800
#  ...                                        ...
#  1750  5964056100 Cable sleeve 200 pieces Sysko
#  1751                   5964073105 - Blade fuse
#  1752     5964076402 - Air-conditioning, ORings
#  1753                    5964511701 - Split Pin
#  1754                            5964558000 Kit
#
#                                    Unnamed: 6  Unnamed: 7  Unnamed: 8  \
#  0                                  LONG TEXT   CLEAN VPN   CLEAN MPN
#  1                  PIN,CONNECTOR;CAT;1809339  6133554007     1809339
#  2     BURR;TUNG-CARB;CYLINDRICAL;6.3X21.64MM   616970003  1616260616
#  3           BURR;TUNG-CARB,ARCHED,13X25X76MM   616970010  1616861325
#  4            SPRAY;300ML;COPPER GREASE;CU800      893800      893800
#  ...                                      ...         ...         ...
#  1750                                     NaN           0         NaN
#  1751                                     NaN           0         NaN
#  1752                                     NaN           0         NaN
#  1753                                     NaN           0         NaN
#  1754                                     NaN           0         NaN
#
#                 Unnamed: 9  ... Unnamed: 18 Unnamed: 19 Unnamed: 20        MPN  \
#  0             SUBCATEGORY  ...       Wurth        HDAL  Common D M  BHP 3.4 M
#  1      Operating Supplies  ...         NaN         NaN         NaN        NaN
#  2     Tools & Instruments  ...         NaN         NaN         NaN        NaN
#  3     Tools & Instruments  ...         NaN         NaN         NaN        NaN
#  4       Oils & Lubricants  ...         NaN         NaN         NaN        NaN
#  ...                   ...  ...         ...         ...         ...        ...
#  1750                    #  ...         NaN         NaN         NaN        NaN
#  1751                    #  ...         NaN         NaN         NaN        NaN
#  1752                    #  ...         NaN         NaN         NaN        NaN
#  1753                    #  ...         NaN         NaN         NaN        NaN
#  1754                    #  ...         NaN         NaN         NaN        NaN
#
#       Unnamed: 22 Unnamed: 23 Exact for spec'd product Unnamed: 25  \
#  0        Wurth M       HDAL2              Coding Team  Alternates
#  1            NaN         NaN                      NaN         NaN
#  2       00702695         NaN                      NaN         NaN
#  3       05506800         NaN                      NaN         NaN
#  4            NaN         NaN                      NaN         NaN
#  ...          ...         ...                      ...         ...
#  1750         NaN         NaN                      NaN         NaN
#  1751         NaN         NaN                      NaN         NaN
#  1752         NaN         NaN                      NaN         NaN
#  1753         NaN         NaN                      NaN         NaN
#  1754         NaN         NaN                      NaN         NaN
#
#          Unnamed: 26    Unnamed: 27
#  0     Right Product  Right Product
#  1               NaN            NaN
#  2          00702695            NaN
#  3          05506800            NaN
#  4               NaN            NaN
#  ...             ...            ...
#  1750            NaN            NaN
#  1751            NaN            NaN
#  1752            NaN            NaN
#  1753            NaN            NaN
#  1754            NaN            NaN
#
#  [1755 rows x 28 columns]}
